# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv("C:/Users/Dev kumar/Downloads/netflix_titles.csv")

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.median()
# Out:
# C:\Users\Dev kumar\AppData\Local\Temp\ipykernel_17140\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# release_year    2017.0
# dtype: float64

# %%
df["director"]=df["director"].fillna("james camron")

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water     james camron
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans     james camron
# 4         s5  TV Show           Kota Factory     james camron
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb     james camron
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.isnull().sum()
# Out:
# show_id           0
# type              0
# title             0
# director          0
# cast            825
# country         831
# date_added       10
# release_year      0
# rating            4
# duration          3
# listed_in         0
# description       0
# dtype: int64

# %%
df[df["director"]=="james camron"]
# Out:
#      show_id     type                                title      director  \
# 1         s2  TV Show                        Blood & Water  james camron
# 3         s4  TV Show                Jailbirds New Orleans  james camron
# 4         s5  TV Show                         Kota Factory  james camron
# 10       s11  TV Show  Vendetta: Truth, Lies and The Mafia  james camron
# 14       s15  TV Show      Crime Stories: India Detectives  james camron
# ...      ...      ...                                  ...           ...
# 8795   s8796  TV Show                      Yu-Gi-Oh! Arc-V  james camron
# 8796   s8797  TV Show                           Yunus Emre  james camron
# 8797   s8798  TV Show                            Zak Storm  james camron
# 8800   s8801  TV Show                   Zindagi Gulzar Hai  james camron
# 8803   s8804  TV Show                          Zombie Dumb  james camron
#
#                                                    cast  \
# ...

# %%
#plt.plot("rating" , "rating" , marker="*" )

# %%
df.query("date_added==2021")
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water     james camron
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans     james camron
# 4         s5  TV Show           Kota Factory     james camron
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb     james camron
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water     james camron
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans     james camron
# 4         s5  TV Show           Kota Factory     james camron
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb     james camron
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.isnull().sum()
# Out:
# show_id           0
# type              0
# title             0
# director          0
# cast            825
# country         831
# date_added       10
# release_year      0
# rating            4
# duration          3
# listed_in         0
# description       0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water     james camron
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans     james camron
# 4         s5  TV Show           Kota Factory     james camron
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb     james camron
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
[df["title"].isin(["Kota Factory"])]
# Out:
# [0       False
#  1       False
#  2       False
#  3       False
#  4        True
#          ...
#  8802    False
#  8803    False
#  8804    False
#  8805    False
#  8806    False
#  Name: title, Length: 8807, dtype: bool]

# %%
df[df["title"].isin(["Kota Factory"])]
# Out:
#   show_id     type         title      director  \
# 4      s5  TV Show  Kota Factory  james camron
#
#                                                 cast country  \
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
#
#            date_added  release_year rating   duration  \
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 4  In a city of coaching centers known to train I...

# %%
df["title"].str.contains("Kota Factory")
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Name: title, Length: 8807, dtype: bool

# %%
df[df["title"].str.contains("Kota Factory")]
# Out:
#   show_id     type         title      director  \
# 4      s5  TV Show  Kota Factory  james camron
#
#                                                 cast country  \
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
#
#            date_added  release_year rating   duration  \
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 4  In a city of coaching centers known to train I...

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df["date_n"]=pd.to_datetime(df["date_added"])

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water     james camron
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans     james camron
# 4         s5  TV Show           Kota Factory     james camron
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb     james camron
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['date_n'].dt.year.value_counts()
# Out:
# 2019.0    2016
# 2020.0    1879
# 2018.0    1649
# 2021.0    1498
# 2017.0    1188
# 2016.0     429
# 2015.0      82
# 2014.0      24
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: date_n, dtype: int64

# %%
df.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# date_n          datetime64[ns]
# dtype: object

# %%
df.release_year =df.release_year.astype("object")

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water     james camron
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans     james camron
# 4         s5  TV Show           Kota Factory     james camron
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb     james camron
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year            object
# rating                  object
# duration                object
# listed_in               object
# description             object
# date_n          datetime64[ns]
# dtype: object

# %%
df['date_n'].dt.year.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df.date_n.value_counts()
# Out:
# 2020-01-01    110
# 2019-11-01     91
# 2018-03-01     75
# 2019-12-31     74
# 2018-10-01     71
#              ...
# 2017-02-21      1
# 2017-02-07      1
# 2017-01-29      1
# 2017-01-25      1
# 2020-01-11      1
# Name: date_n, Length: 1714, dtype: int64

# %%
# how many movies and shows in data set show with bar graph

# %%
# 1.by groupby

# %%
df.groupby("type").type.value_counts()
# Out:
# type     type
# Movie    Movie      6131
# TV Show  TV Show    2676
# Name: type, dtype: int64

# %%
# 2. countplot

# %%
sns.countplot(df["type"])
# Out:
# C:\Users\Dev kumar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
df[df.query("release_year==2020")]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [45], in <cell line: 1>()
# ----> 1 df[df.query("release_year==2020")]
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3492, in DataFrame.__getitem__(self, key)
#    3490 # Do we have a (boolean) DataFrame?
#    3491 if isinstance(key, DataFrame):
# -> 3492     return self.where(key)
#    3494 # Do we have a (boolean) 1d indexer?
#    3495 if com.is_bool_indexer(key):
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
# show all the movies that were relised in particular year

# %%
# creating new column

# %%
df["movie_relised in 2020"]=df["date_n"].dt.year

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water     james camron
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans     james camron
# 4         s5  TV Show           Kota Factory     james camron
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb     james camron
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
(df["type"]=="Movie") & (df["movie_relised in 2020"]=="2020")
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
df["desh"]=df["country"].sort_values()

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water     james camron
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans     james camron
# 4         s5  TV Show           Kota Factory     james camron
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb     james camron
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df[(df["type"]=="Movie") & (df["country"]=="India")]
# Out:
#      show_id   type                  title                 director  \
# 24       s25  Movie                  Jeans               S. Shankar
# 105     s106  Movie       Angamaly Diaries     Lijo Jose Pellissery
# 114     s115  Movie                 Anjaam             Rahul Rawail
# 116     s117  Movie                 Dhanak          Nagesh Kukunoor
# 118     s119  Movie                Gurgaon            Shanker Raman
# ...      ...    ...                    ...                      ...
# 8772   s8773  Movie  Yamla Pagla Deewana 2           Sangeeth Sivan
# 8773   s8774  Movie    Yanda Kartavya Aahe             Kedar Shinde
# 8798   s8799  Movie               Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800  Movie                  Zenda           Avadhoot Gupte
# 8806   s8807  Movie                 Zubaan              Mozez Singh
#
#                                                    cast country  \
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...   India
# ...

# %%
df[(df["type"]=="Movie") & (df["country"]=="India")] ["title"]
# Out:
# 24                      Jeans
# 105          Angamaly Diaries
# 114                    Anjaam
# 116                    Dhanak
# 118                   Gurgaon
#                 ...
# 8772    Yamla Pagla Deewana 2
# 8773      Yanda Kartavya Aahe
# 8798                 Zed Plus
# 8799                    Zenda
# 8806                   Zubaan
# Name: title, Length: 893, dtype: object

# %%
 # df[(df["type"]=="Movie") & (df["country"]=="India")] ["title"].plot(kind="bar")

# %%
df["director"].value_counts()
# Out:
# james camron                      2634
# Rajiv Chilaka                       19
# Raúl Campos, Jan Suter              18
# Suhas Kadav                         16
# Marcus Raboy                        16
#                                   ...
# Raymie Muzquiz, Stu Livingston       1
# Joe Menendez                         1
# Eric Bross                           1
# Will Eisenberg                       1
# Mozez Singh                          1
# Name: director, Length: 4529, dtype: int64

# %%
df["director"].value_counts().head(2)plot(kind="bar")
# Out:
#   Input In [57]
#     df["director"].value_counts().head(2)plot(kind="bar")
#                                          ^
# SyntaxError: invalid syntax

# %%
df[df["director"]=="james camron"]
# Out:
#      show_id     type                                title      director  \
# 1         s2  TV Show                        Blood & Water  james camron
# 3         s4  TV Show                Jailbirds New Orleans  james camron
# 4         s5  TV Show                         Kota Factory  james camron
# 10       s11  TV Show  Vendetta: Truth, Lies and The Mafia  james camron
# 14       s15  TV Show      Crime Stories: India Detectives  james camron
# ...      ...      ...                                  ...           ...
# 8795   s8796  TV Show                      Yu-Gi-Oh! Arc-V  james camron
# 8796   s8797  TV Show                           Yunus Emre  james camron
# 8797   s8798  TV Show                            Zak Storm  james camron
# 8800   s8801  TV Show                   Zindagi Gulzar Hai  james camron
# 8803   s8804  TV Show                          Zombie Dumb  james camron
#
#                                                    cast  \
# ...

# %%
df[df["cast"]=="Tom cruise"]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, date_n, movie_relised in 2020, desh]
# Index: []

# %%
df["rating"].nunique()
# Out:
# 17

# %%
df["rating"].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
df[(df["type"]=="Movie") & (df["rating"]=="TV-14")]
# Out:
#      show_id   type                                              title  \
# 18       s19  Movie                                          Intrusion
# 24       s25  Movie                                              Jeans
# 30       s31  Movie                                    Ankahi Kahaniya
# 51       s52  Movie  InuYasha the Movie 2: The Castle Beyond the Lo...
# 52       s53  Movie  InuYasha the Movie 3: Swords of an Honorable R...
# ...      ...    ...                                                ...
# 8772   s8773  Movie                              Yamla Pagla Deewana 2
# 8774   s8775  Movie                                          يوم الدين
# 8794   s8795  Movie                                             اشتباك
# 8799   s8800  Movie                                              Zenda
# 8806   s8807  Movie                                             Zubaan
#
#                                                director  \
# 18                                           Adam Salky
# ...

# %%
df[(df["type"]=="Movie") & (df["rating"]=="TV-14") & (df["country"]=="India")]
# Out:
#      show_id   type                  title              director  \
# 24       s25  Movie                  Jeans            S. Shankar
# 105     s106  Movie       Angamaly Diaries  Lijo Jose Pellissery
# 114     s115  Movie                 Anjaam          Rahul Rawail
# 118     s119  Movie                Gurgaon         Shanker Raman
# 126     s127  Movie                Shikara    Vidhu Vinod Chopra
# ...      ...    ...                    ...                   ...
# 8770   s8771  Movie                Yaadein          Subhash Ghai
# 8771   s8772  Movie       Yaara O Dildaara    Ksshitij Chaudhary
# 8772   s8773  Movie  Yamla Pagla Deewana 2        Sangeeth Sivan
# 8799   s8800  Movie                  Zenda        Avadhoot Gupte
# 8806   s8807  Movie                 Zubaan           Mozez Singh
#
#                                                    cast country  \
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...   India
# ...

# %%
df[(df["type"]=="Movie") & (df["listed_in"]=="Comedies") & (df["country"]=="India")]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, date_n, movie_relised in 2020, desh]
# Index: []

# %%
df[(df["type"]=="Movie") & (df["rating"]=="TV-14") & (df["country"]=="India") & (df["release_year"]> 2020)]
# Out:
#      show_id   type                 title                 director  \
# 190     s191  Movie            Thimmarusu        Sharan Koppisetty
# 850     s851  Movie              99 Songs  Vishwesh Krishnamoorthy
# 871     s872  Movie    Sardar Ka Grandson            Kaashvie Nair
# 909     s910  Movie             Milestone                 Ivan Ayr
# 998     s999  Movie  Searching For Sheela             james camron
# 1037   s1038  Movie    Tuesdays & Fridays          Taranveer Singh
# 1087   s1088  Movie                 Roohi             Hardik Mehta
# 1098   s1099  Movie               Mandela           Madonne Ashwin
# 1202   s1203  Movie           C/O Kaadhal           Hemambar Jasti
# 1230   s1231  Movie                 Aelay          Halitha Shameem
# 1281   s1282  Movie                   Red         Tirumala Kishore
#
#                                                    cast country  \
# 190              Satya Dev, Priyanka Jawalkar, Brahmaji   India
# ...

# %%
df["duration"].unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
df["duration"].nunique()
# Out:
# 220

# %%
df.duration.unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
df.duration.dtypes
# Out:
# dtype('O')

# %%
df[["Minutes", "Unites"]]=df["duration"].str.split(" ", expand=True)

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water     james camron
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans     james camron
# 4         s5  TV Show           Kota Factory     james camron
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb     james camron
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.Minutes.isnull().sum()
# Out:
# 3

# %%
df.Minutes.dtypes
# Out:
# dtype('O')

# %%
df.head(2)

# %%
data_tvshows=df[df["type"]=="TV Show"]

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water     james camron
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans     james camron
# 4         s5  TV Show           Kota Factory     james camron
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb     james camron
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data_tvshows=df[df["type"]=="Movie"]

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water     james camron
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans     james camron
# 4         s5  TV Show           Kota Factory     james camron
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb     james camron
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water     james camron
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added release_year rating   duration  \
# 0  September 25, 2021         2020  PG-13     90 min
# 1  September 24, 2021         2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     date_n  \
# 0  As her father nears the end of his life, filmm... 2021-09-25
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24
#
#    movie_relised in 2020           desh Minutes   Unites
# ...

# %%
df.sort_values(by="release_year", ascending=False).head(2)
# Out:
#     show_id   type                                  title        director  \
# 693    s694  Movie                 Ali & Ratu Ratu Queens  Lucky Kuswandi
# 781    s782  Movie  Black Holes | The Edge of All We Know   Peter Galison
#
#                                                   cast country     date_added  \
# 693  Iqbaal Ramadhan, Nirina Zubir, Asri Welas, Tik...     NaN  June 17, 2021
# 781                                                NaN     NaN   June 2, 2021
#
#     release_year rating duration                               listed_in  \
# 693         2021  TV-14  101 min  Comedies, Dramas, International Movies
# 781         2021  TV-14   99 min                           Documentaries
#
#                                            description     date_n  \
# 693  After his father's passing, a teenager sets ou... 2021-06-17
# 781  Follow scientists on their quest to understand... 2021-06-02
#
#      movie_relised in 2020 desh Minutes Unites
# ...

# %%
df[(df["type"]=="Movie") & (df["listed_in"]=="Documentaries")].head(2)
# Out:
#    show_id   type                   title         director cast  \
# 0       s1  Movie    Dick Johnson Is Dead  Kirsten Johnson  NaN
# 45     s46  Movie  My Heroes Were Cowboys      Tyler Greco  NaN
#
#           country          date_added release_year rating duration  \
# 0   United States  September 25, 2021         2020  PG-13   90 min
# 45            NaN  September 16, 2021         2021     PG   23 min
#
#         listed_in                                        description  \
# 0   Documentaries  As her father nears the end of his life, filmm...
# 45  Documentaries  Robin Wiltshire's painful childhood was rescue...
#
#        date_n  movie_relised in 2020           desh Minutes Unites
# 0  2021-09-25                 2021.0  United States      90    min
# 45 2021-09-16                 2021.0            NaN      23    min

# %%
df[(df["type"]=="Movie") & (df["listed_in"]=="Documentaries") | (df["type"]=="Movie") & (df["country"]=="United States")]
# Out:
#      show_id   type                 title          director  \
# 0         s1  Movie  Dick Johnson Is Dead   Kirsten Johnson
# 9        s10  Movie          The Starling    Theodore Melfi
# 27       s28  Movie             Grown Ups      Dennis Dugan
# 28       s29  Movie            Dark Skies     Scott Stewart
# 41       s42  Movie                  Jaws  Steven Spielberg
# ...      ...    ...                   ...               ...
# 8791   s8792  Movie           Young Adult     Jason Reitman
# 8793   s8794  Movie  Yours, Mine and Ours      Raja Gosnell
# 8802   s8803  Movie                Zodiac     David Fincher
# 8804   s8805  Movie            Zombieland   Ruben Fleischer
# 8805   s8806  Movie                  Zoom      Peter Hewitt
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...  United States
# ...

# %%
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                   james camron
# 2                Julien Leclercq
# 3                   james camron
# 4                   james camron
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...
